# %%
# !python run.py

# %%
# !pip install zenml
# !zenml init
# !pip install mlflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 20.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 53.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/14 [zenml]m13/14 [zenml]]c]
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip
# Initializing the ZenML global configuration version to 0.91.2
# ⠋ Initializing ZenML repository at /workspaces/codespaces-jupyter.
#
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /home/codespace/.python/current/bin/zenml:8 in <module>                      │
# │                                                                              │
# │   5 from zenml.cli.cli import cli                                            │
# │   6 if __name__ == '__main__':                                               │
# ...
